# %%
import calendar
import random

def make_schedule(staff, year, month):
    shifts = ["7:00 AM - 1:00 PM", "1:00 PM - 7:00 PM"]

    num_of_days = calendar.monthrange(year,month)[1]

    schedule = {}
    for day in range(1, num_of_days + 1):
        schedule[day] = {
            shifts[0]: random.choice(staff).
            shifts[1]: random.choice(staff)
        }

def display_schedule_as_html(schedule, year, month):
    html_schedule = f"""
    <html>
    <head>
        <title>Work Schedule for {calendar.month_name[month]} {year}</title>
        <style>
            table {{
                border-collapse: collapse;
                width: 100%;
                margin: 20px 0;
            }}
            th, td {{
                border: 1px solid black;
                padding: 10px;
                text-align: center;
            }}
            th {{
                background-color: #f2f2f2;
            }}
            td {{
                height: 100px;
                vertical-align: top;
            }}
        </style>
    </head>
    <body>
        <h1>Work Schedule for {calendar.month_name[month]} {year}</h1>
        <table>
            <tr>
                <th>Mon</th>
                <th>Tue</th>
                <th>Wed</th>
                <th>Thu</th>
                <th>Fri</th>
                <th>Sat</th>
                <th>Sun</th>
            </tr>
    """
    first_weekday, num_of_days = calendar.monthrange(year, month)

    current_day = 1
    for week in range((num_of_days + first_weekday) // 7 + 1):
        html_schedule += "<tr>"
        for day in range(7):
            if (week == 0 and day < first_weekday) or current_day > num_of_days:
                html_schedule += "<td></td>"
            else:
                day_shifts = schedule.get(current_day, {})
                morning = day_shift.get("7:00 AM - 1:00 PM", "N/A")
                afternoon = day_shift.get("1:00 PM - 7:00 PM", "N/A")

                html_schedule += f"<td>{current_day}<br><b>AM:</b> {morning}<b><b>PM:</b>{afternoon}</td>"
                current_day += 1
            html_schedule += "</tr>"

        html_schedule += """
            </table>
        </body>
        </html>
        """

        with open(f"work_schedule_{year}_{month}.html", "w") as file:
            file.write(html_schedule)

        print(f"HTML work schedule for {calendar.month_name[month]} {year} generated successfully!")

    staff = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace"]
    year = int(inpot("Enter the year: "))
    month = int(input("Enter the month (1-12): "))

    schedule = generate_schedule(staff, year, month)

    display_schedule_as_html(schedule, year, month)
# Out:
#   Cell In[3], line 13
#     shifts[1]: random.choice(staff)
#              ^
# SyntaxError: invalid syntax
